# %% [markdown]
# ## Dataset Klasifikasi Kesuburan Tanah
# ###Analisa Data Kesuburan Tanah
# 1. Lakukan analisis data dengan menggunakan
# K-Nearest Neighbors (KNN)
# 2. Lakukan Pemrosesan Data tersebut
# 3. Hitung Metrik Evaluasi
# |Metrik|Keterangan|
# |------|----------|
# |Accuracy|Persentase prediksi benar dari total data
# |Precision|Ketepatan prediksi kelas positif|
# |Recall|Kemampuan mendeteksi seluruh kelas positif|
# |F1-Score|Harmonic mean antara Precision dan Recall|
#
# ### Deskripsi Umum
# Dataset berisi 2.000 sampel data tanah dengan 10 fitur agronomis dan 1 kolom label yang membagi kondisi tanah menjadi dua kelas: Subur dan Tidak Subur. Data mengandung missing values (data hilang)
#
# ###Informasi Dataset
# |Atribut|Keterangan|
# |-------|----------|
# |Jumlah Sampel|2.000|baris|
# |Jumlah Fitur|10 fitur (9 numerik, 1 kategorikal)|
# |Jumlah Kelas|2 kelas|
# |Target / Label|Subur / Tidak Subur|
#
# ###Penjelasan Fitur
# 1. pH Tanah
# - Satuan: Skala pH (0–14)
# - Deskripsi: Tingkat keasaman atau kebasaan tanah. pH optimal untuk pertanian berkisar 6,0–7,5.
# - Nilai Subur: 6,0 – 7,5
# - Nilai Tidak Subur: 3,5 – 5,4 (asam kuat) atau 7,6 – 9,0 (basa kuat)
# 2. N Total (%)
# - Satuan: Persen (%)
# - Deskripsi: Kandungan nitrogen total dalam tanah. Nitrogen sangat penting untuk pertumbuhan vegetatif tanaman.
# - Nilai Subur: 0,21 – 0,50%
# - Nilai Tidak Subur: 0,01 – 0,20%
# 3. P Tersedia (ppm)
# - Satuan: Parts per million (ppm)
# - Deskripsi: Fosfor tersedia yang dapat diserap tanaman. Fosfor berperan dalam pembentukan akar dan buah.
# - Nilai Subur: 15 – 60 ppm
# - Nilai Tidak Subur: 1 – 14 ppm
# 4. K Tersedia (meq/100g)
# - Satuan: Milliequivalent per 100 gram tanah
# - Deskripsi: Kalium tersedia dalam tanah. Penting untuk ketahanan tanaman dan proses fotosintesis.
# - Nilai Subur: 0,30 – 0,80 meq/100g
# - Nilai Tidak Subur: 0,05 – 0,29 meq/100g
# 5. C Organik (%)
# - Satuan: Persen (%)
# - Deskripsi: Kandungan karbon organik tanah, indikator utama kesuburan dan kesehatan biologi tanah.
# - Nilai Subur: 2,0 – 5,0%
# - Nilai Tidak Subur: 0,2 – 1,9%
# 6. KTK (meq/100g)
# - Satuan: Milliequivalent per 100 gram tanah
# - Deskripsi: Kapasitas Tukar Kation — kemampuan tanah mengikat dan menyediakan unsur hara bagi tanaman. Semakin tinggi semakin subur.
# - Nilai Subur: 20 – 45 meq/100g
# - Nilai Tidak Subur: 5 – 19 meq/100g
# 7. Kejenuhan Basa (%)
# - Satuan: Persen (%)
# - Deskripsi: Persentase kation basa (Ca, Mg, K, Na) dari total KTK. Menggambarkan kualitas kesuburan kimia tanah.
# - Nilai Subur: 60 – 100%
# - Nilai Tidak Subur: 10 – 59%
# 8. Tekstur Tanah
# - Tipe: Kategorikal
# - Deskripsi: Komposisi partikel tanah yang memengaruhi drainase, aerasi, dan kemampuan menahan air.
# |kelas|tekstur yang umum|
# |-----|-----------------|
# |subur|Lempung, Lempung Berpasir, Lempung Berliat|
# |tidak subur|Pasir, Liat, Debu|
# 9. Kadar Air (%)
# - Satuan: Persen (%)
# - Deskripsi: Persentase kadar air dalam tanah. Terlalu kering atau terlalu basah sama-sama merugikan pertumbuhan tanaman.
# - Nilai Subur: 25 – 45%
# - Nilai Tidak Subur: 5 – 20% (terlalu kering) atau 55 – 75% (terlalu basah)
# 10. Bulk Density (g/cm³)
# - Satuan: Gram per sentimeter kubik
# - Deskripsi: Kerapatan tanah. Nilai tinggi menandakan tanah padat, aerasi buruk, dan sulit ditembus akar.
# - Nilai Subur: 0,9 – 1,2 g/cm³
# - Nilai Tidak Subur: 1,4 – 1,9 g/cm³
#
# ###Definisi Kelas
#
# |Label|Deskripsi|
# |-----|---------|
# |Subur|Tanah dengan kondisi fisik, kimia, dan biologi yang optimal untuk pertumbuhan tanaman. Ditandai dengan pH seimbang, unsur hara cukup, tekstur ideal, dan struktur tanah yang baik.|
# |Tidak Subur|Tanah yang memiliki satu atau lebih kondisi pembatas seperti pH ekstrem, kekurangan unsur hara, tekstur buruk, kadar air tidak ideal, atau kerapatan tanah tinggi.|
#
#
#
# ###Tampilan Dataset Awal
# ![data set.png](data:image/png;base64,...)
# ###Informasi statistik kolom
# ![colum statistik.png](data:image/png;base64,...)
# ###Distribusi Kelas
#
# ###Preprocessing Data
# ####normalisasi data
# ![normalisasi.png](data:image/png;base64,...)
# ###Missing Value
# ![input.png](data:image/png;base64,...)
# ###Hasil Preprocessing
#
# ###Metode KNN
# ![Screenshot_2.pngknn.png.png](data:image/png;base64,...)
# ###Hasil Evaluasi
# ####Test & Score
# ![test&scoore.png](data:image/png;base64,...)
# ####Confusion Matrix
# ![matrix.png](data:image/png;base64,...)
#
# ###1.Analisis Data Menggunakan KNN
#  Konsep KNN
# KNN adalah algoritma supervised learning yang bekerja dengan cara:
# - Menghitung jarak antara data uji dengan seluruh data latih
# - Memilih **k tetangga terdekat**
# - Menentukan kelas berdasarkan mayoritas tetangga
#
# ####Penerapan pada Dataset
#
# - **Input (Fitur):**
#   - pH Tanah
#   - N Total
#   - P Tersedia
#   - K Tersedia
#   - C Organik
#   - KTK
#   - Kejenuhan Basa
#   - Tekstur Tanah
#   - Kadar Air
#   - Bulk Density
#
# - **Target (Label):**
#   - Subur
#   - Tidak Subur
#
# ###2. Pemrosesan Data (Preprocessing)
# #### a. Select Columns
# - Menentukan:
#   - **Fitur (X)** → semua atribut kecuali label
#   - **Target (Y)** → kolom kesuburan tanah
#
# Tujuan: agar model mengetahui input dan output yang akan diprediksi.
#
# ####b. Handling Missing Value (Impute)
# - Dataset memiliki data kosong (missing values)
# - Penanganan:
#   - Mean → untuk data numerik
#   - Modus → untuk data kategorikal
#
# Tujuan: agar tidak ada nilai kosong yang mengganggu proses KNN.
# ####c. Transformasi Data (Continuize)
# - Data kategorikal seperti *Tekstur Tanah* diubah menjadi numerik
#
# Contoh:
# - Lempung → 1
# - Pasir → 0
#
# Tujuan: karena KNN membutuhkan data numerik untuk menghitung jarak.
# #### d. Normalisasi Data (Opsional)
# - Menyamakan skala antar fitur
# - Contoh metode:
#   - Min-Max Scaling
#   - Z-Score
#
# Tujuan: agar tidak ada fitur yang mendominasi perhitungan jarak.
#
# ###3. Proses Klasifikasi dengan KNN
# Langkah-langkah:
# 1. Menentukan nilai **K** (misalnya K = 3 atau 5)
# 2. Menghitung jarak (Euclidean Distance)
# 3. Mengambil K tetangga terdekat
# 4. Menentukan kelas berdasarkan mayoritas
#
# ###4. Evaluasi Model
# Evaluasi dilakukan menggunakan:
# - Test and Score
# - Confusion Matrix
#
# Confusion Matrix
# - **True Positive (TP)** → Subur diprediksi Subur
# - **True Negative (TN)** → Tidak Subur diprediksi Tidak Subur
# - **False Positive (FP)** → Tidak Subur diprediksi Subur
# - **False Negative (FN)** → Subur diprediksi Tidak Subur
#
# ###5. Perhitungan Metrik Evaluasi
# Rumus:
#
# **Accuracy**
# $$
# Accuracy = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# **Precision**
# $$
# Precision = \frac{TP}{TP + FP}
# $$
#
# **Recall**
# $$
# Recall = \frac{TP}{TP + FN}
# $$
#
# **F1-Score**
# $$
# F1 = 2 \times \frac{Precision \times Recall}{Precision + Recall}
# $$
#
# ###6. Interpretasi Metrik
#
# - **Accuracy**
#   - Mengukur keseluruhan prediksi benar
#
# - **Precision**
#   - Ketepatan prediksi kelas Subur
#
# - **Recall**
#   - Kemampuan model mendeteksi semua data Subur
#
# - **F1-Score**
#   - Keseimbangan antara Precision dan Recall
#
# ###7. Kesimpulan
# - Algoritma KNN dapat digunakan untuk klasifikasi kesuburan tanah
# - Preprocessing sangat penting karena:
#   - Terdapat missing value
#   - Ada data kategorikal
# - Evaluasi menggunakan Accuracy, Precision, Recall, dan F1-Score memberikan gambaran performa model secara menyeluruh
